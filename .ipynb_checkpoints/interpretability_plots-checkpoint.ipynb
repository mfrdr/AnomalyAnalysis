# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import torch
from graphino.GCN.GCN_model import GCN
from graphino.GCN.GCN_model_2 import GCN_2
from graphino.training import get_static_feats
from utilities.data_wrangling import load_cnn_data
from utilities.plotting import plot_centrality_from_adj, plot_centrality_from_2_adj
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Eigenvector Centrality Heatmaps of the learned world connectivity structure
# ## $-$ This notebook corresponds to Fig. 2 in the paper
#
# It will reload all pre-trained models corresponding to th Fig. 2 plots, and compute
# the eigenvector centrality score of all nodes, to then produce a heatmap of them.
# The used models have the strongest performance among the four ensemble members reported in our main results.

# %%
def reload_and_plot_eigv_centrality(model_dir, lead_months, data_dir=None, device='cuda', ID='50ep_'):
    out = f'out/{lead_months}lead/'
    print("IN")
    try:
        model_dir = out + model_dir
        model_dict = torch.load(os.path.join(model_dir, ID + '_model.pkl'))
    except FileNotFoundError as e:
        print(e)
        return
    params, net_params = model_dict['metadata']['params'], model_dict['metadata']['net_params']
    load_data_kwargs = {
        'window': params['window'], 'lead_months': params['horizon'], 'lon_min': params['lon_min'],
        'lon_max': params['lon_max'], 'lat_min': params['lat_min'], 'lat_max': params['lat_max'],
        'data_dir': params['data_dir'], 'use_heat_content': params['use_heat_content'],
        'add_index_node': net_params['index_node'], 
    }
    if data_dir is not None:
        load_data_kwargs['data_dir'] = data_dir
    cmip5, SODA, GODAS, cords = load_cnn_data(**load_data_kwargs,
                                                return_new_coordinates=True,
                                                return_mask=False, verbose=False)
    static_feats = get_static_feats(params, net_params, cords, SODA[0])
    lats, lons = GODAS[0].attrs["Lats"], GODAS[0].attrs["Lons"]
    
    model = GCN(net_params, static_feat=static_feats, verbose=False)
    state_dict = model_dict['model']
    model.load_state_dict(state_dict)
    model.eval()
    model.to(device)
    
    adj = model.graph_learner().detach().cpu().numpy()
    if net_params['index_node']:  # do not plot the index node
        adj = adj[:-1, :-1]
    plot_centrality_from_adj(adj, lats, lons, coordinates=cords, save_to=None, set_title=False, verbose=False,
                                    min_weight=0, show=True, horizon=params['horizon'])

# %%
def reload_and_plot_eigv_centrality_2(model_dir, lead_months, data_dir=None, device='cuda', ID='last_2'):
    out = f'out/{lead_months}lead/'
    print(ID)
    try:
        model_dir = out + model_dir
        model_dict = torch.load(os.path.join(model_dir, ID + '_model.pkl'))
    except FileNotFoundError as e:
        print(e)
        return
    params, net_params = model_dict['metadata']['params'], model_dict['metadata']['net_params']
    load_data_kwargs = {
        'window': params['window'], 'lead_months': params['horizon'], 'lon_min': params['lon_min'],
        'lon_max': params['lon_max'], 'lat_min': params['lat_min'], 'lat_max': params['lat_max'],
        'data_dir': params['data_dir'], 'use_heat_content': params['use_heat_content'],
        'add_index_node': net_params['index_node'], 
    }
    if data_dir is not None:
        load_data_kwargs['data_dir'] = data_dir
    cmip5, SODA, GODAS, cords = load_cnn_data(**load_data_kwargs,
                                                return_new_coordinates=True,
                                                return_mask=False, verbose=False)
    static_feats = get_static_feats(params, net_params, cords, SODA[0])
    lats, lons = GODAS[0].attrs["Lats"], GODAS[0].attrs["Lons"]
    
    model = GCN_2(net_params, static_feat=static_feats, verbose=False)
    state_dict = model_dict['model']
    model.load_state_dict(state_dict)
    model.eval()
    model.to(device)
    
    adj_atm = model.graph_learner_atm().detach().cpu().numpy()
    adj_oc = model.graph_learner_oc().detach().cpu().numpy()

    # If the model uses an index node, remove it
    if net_params['index_node']:
        adj_atm = adj_atm[:-1, :-1]
        adj_oc = adj_oc[:-1, :-1]
        
    plot_centrality_from_2_adj(adj_atm, adj_oc, lats, lons, coordinates=cords, save_to=None, set_title=True, verbose=False,
                                    min_weight=0, show=True, horizon=params['horizon'])

# %%
kwargs = {
    'device': 'cuda',
    'ID': 'last', 
    'data_dir': './Data/'
}

# %%
import time
time.sleep(2)
print("Kernel is responsive!")
# Out:
# Kernel is responsive!

# %% [markdown]
# # 3 lead 2 adj

# %%
reload_and_plot_eigv_centrality('250x250_21h10m22s_on_Apr_05_2025', lead_months=1, **kwargs)
# Out:
# IN
# CMIP5.input.36mn.1861_2001.nc
# (141, 12)
# Filtered region lat size: 24
# Expected lat size: 24
# SODA.input.36mn.1871_1970.nc
# (100, 12)
# Filtered region lat size: 24
# Expected lat size: 24
# GODAS.input.36mn.1980_2012.nc
# (33, 12)
# Filtered region lat size: 24
# Expected lat size: 24
# SHAPES BEFORE: (1692, 2, 3, 1728) (1200, 2, 3, 1728) (372, 2, 3, 1728)
# SHAPES: (1692, 2, 3, 1728) (1200, 2, 3, 1728) (372, 2, 3, 1728)
# (1729, 2) (1200, 1729)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipykernel_278824/4217469087.py in <module>
# ----> 1 reload_and_plot_eigv_centrality('250x250_21h10m22s_on_Apr_05_2025', lead_months=1, **kwargs)
#
# /tmp/ipykernel_278824/1287471330.py in reload_and_plot_eigv_centrality(model_dir, lead_months, data_dir, device, ID)
#      25     model = GCN(net_params, static_feat=static_feats, verbose=False)
#      26     state_dict = model_dict['model']
# ---> 27     model.load_state_dict(state_dict)
#      28     model.eval()
#      29     model.to(device)
#
# ~/.conda/envs/graphino/lib/python3.7/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1603         if len(error_msgs) > 0:
#    1604             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# -> 1605                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1606         return _IncompatibleKeys(missing_keys, unexpected_keys)
#    1607
#
# RuntimeError: Error(s) in loading state_dict for GCN:
# 	size mismatch for layers.0.weight: copying a param with shape torch.Size([6, 250]) from checkpoint, the shape in current model is torch.Size([3, 250]).

# %%
reload_and_plot_eigv_centrality_('250x250_18h54m35s_on_Mar_24_2025', lead_months=3, **kwargs)

# %%
reload_and_plot_eigv_centrality('250x250x250_Mean+Sum_18h54m35s_on_Mar_24_2025', lead_months=3, **kwargs)

# %%
reload_and_plot_eigv_centrality('200x200x200_Mean+Sum_18h54m35s_on_Mar_24_2025', lead_months=3, **kwargs)

# %% [markdown]
# # 3 lead

# %%
reload_and_plot_eigv_centrality('250x250', lead_months=3, **kwargs)
# Out:
# IN
# [Errno 2] No such file or directory: 'out/3lead/250x250/last_model.pkl'

# %% [markdown]
# # 6 lead

# %%
reload_and_plot_eigv_centrality('200x200x200_Mean+Sum', lead_months=3, **kwargs)
# Out:
# IN
# [Errno 2] No such file or directory: 'out/3lead/200x200x200_Mean+Sum/last_model.pkl'

# %%
reload_and_plot_eigv_centrality('250x250x250_Mean+Sum', lead_months=3, **kwargs)

# %% [markdown]
# # 9 lead

# %%
reload_and_plot_eigv_centrality('250x250', lead_months=9, **kwargs)

# %% [markdown]
# # 12 lead

# %%
reload_and_plot_eigv_centrality('200x200x200_Mean+Sum', lead_months=12, **kwargs)

# %% [markdown]
# # 23 lead

# %%
reload_and_plot_eigv_centrality('200x200x200_Mean+Sum', lead_months=23, **kwargs)
